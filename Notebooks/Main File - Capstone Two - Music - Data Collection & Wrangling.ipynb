# %% [markdown]
# # Spotify Music Popularity Capstone - Data Collection & Wrangling
#
# Greg Welliver

# %%
# Import relevant libraries and packages.
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import statsmodels.api as sm
from statsmodels.graphics.api import abline_plot
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn import linear_model, preprocessing 
import warnings
from scipy import stats
import re

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
#import sys

credentials = []
f = open('credentials.txt', 'r')
for line in f:
    #add line to credentials list (remove trailing whitespace characters)
    credentials.append(line.rstrip())

# create Spotify object with credentials
client_credentials_manager = SpotifyClientCredentials(credentials[0], credentials[1])
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
### Links to Top Hits Spotify playlists

topLink2021 = "https://open.spotify.com/playlist/5GhQiRkGuqzpWZSE7OU4Se"
topLink2020 = "https://open.spotify.com/playlist/2fmTTbBkXi8pewbUvG3CeZ"
topLink2019 = "https://open.spotify.com/playlist/37i9dQZF1DWVRSukIED0e9"
topLink2018 = "https://open.spotify.com/playlist/37i9dQZF1DXe2bobNYDtW8"
topLink2017 = "https://open.spotify.com/playlist/37i9dQZF1DWTE7dVUebpUW"
topLink2016 = "https://open.spotify.com/playlist/37i9dQZF1DX8XZ6AUo9R4R"
topLink2015 = "https://open.spotify.com/playlist/37i9dQZF1DX9ukdrXQLJGZ"
topLink2014 = "https://open.spotify.com/playlist/37i9dQZF1DX0h0QnLkMBl4"
topLink2013 = "https://open.spotify.com/playlist/37i9dQZF1DX3Sp0P28SIer"
topLink2012 = "https://open.spotify.com/playlist/37i9dQZF1DX0yEZaMOXna3"
topLink2011 = "https://open.spotify.com/playlist/37i9dQZF1DXcagnSNtrGuJ"
topLink2010 = "https://open.spotify.com/playlist/37i9dQZF1DXc6IFF23C9jj"
topLink2009 = "https://open.spotify.com/playlist/37i9dQZF1DX4UkKv8ED8jp"
topLink2008 = "https://open.spotify.com/playlist/37i9dQZF1DWYuGZUE4XQXm"
topLink2007 = "https://open.spotify.com/playlist/37i9dQZF1DX3j9EYdzv2N9"
topLink2006 = "https://open.spotify.com/playlist/37i9dQZF1DX1vSJnMeoy3V"
topLink2005 = "https://open.spotify.com/playlist/37i9dQZF1DWWzQTBs5BHX9"
topLink2004 = "https://open.spotify.com/playlist/37i9dQZF1DWTWdbR13PQYH"
topLink2003 = "https://open.spotify.com/playlist/37i9dQZF1DXaW8fzPh9b08"
topLink2002 = "https://open.spotify.com/playlist/37i9dQZF1DX0P7PzzKwEKl"
topLink2001 = "https://open.spotify.com/playlist/37i9dQZF1DX9Ol4tZWPH6V"
topLink2000 = "https://open.spotify.com/playlist/37i9dQZF1DWUZv12GM5cFk"

allLinks = [topLink2000, topLink2001, topLink2002, topLink2003, topLink2004, topLink2005, topLink2006, topLink2007, topLink2008, topLink2009, topLink2010, topLink2011, topLink2012, topLink2013, topLink2014, topLink2015, topLink2016, topLink2017, topLink2018, topLink2019, topLink2020, topLink2021]

allLinks2 = ["https://open.spotify.com/playlist/5GhQiRkGuqzpWZSE7OU4Se", "https://open.spotify.com/playlist/2fmTTbBkXi8pewbUvG3CeZ"]

allLinks3 = [topLink2018, topLink2019, topLink2020, topLink2021]

# %%
#YearDictionary = {"https://open.spotify.com/playlist/5GhQiRkGuqzpWZSE7OU4Se": 2021, "https://open.spotify.com/playlist/2fmTTbBkXi8pewbUvG3CeZ": 2020, "https://open.spotify.com/playlist/37i9dQZF1DWVRSukIED0e9": 2019}
YearDictionary = {"https://open.spotify.com/playlist/5GhQiRkGuqzpWZSE7OU4Se": 2021, "https://open.spotify.com/playlist/2fmTTbBkXi8pewbUvG3CeZ": 2020, "https://open.spotify.com/playlist/37i9dQZF1DWVRSukIED0e9": 2019, "https://open.spotify.com/playlist/37i9dQZF1DXe2bobNYDtW8": 2018, "https://open.spotify.com/playlist/37i9dQZF1DWTE7dVUebpUW": 2017, "https://open.spotify.com/playlist/37i9dQZF1DX8XZ6AUo9R4R": 2016, "https://open.spotify.com/playlist/37i9dQZF1DX9ukdrXQLJGZ": 2015, "https://open.spotify.com/playlist/37i9dQZF1DX0h0QnLkMBl4": 2014, "https://open.spotify.com/playlist/37i9dQZF1DX3Sp0P28SIer": 2013, "https://open.spotify.com/playlist/37i9dQZF1DX0yEZaMOXna3": 2012, "https://open.spotify.com/playlist/37i9dQZF1DXcagnSNtrGuJ": 2011, "https://open.spotify.com/playlist/37i9dQZF1DXc6IFF23C9jj": 2010, "https://open.spotify.com/playlist/37i9dQZF1DX4UkKv8ED8jp": 2009, "https://open.spotify.com/playlist/37i9dQZF1DWYuGZUE4XQXm": 2008, "https://open.spotify.com/playlist/37i9dQZF1DX3j9EYdzv2N9": 2007, "https://open.spotify.com/playlist/37i9dQZF1DX1vSJnMeoy3V": 2006, "https://open.spotify.com/playlist/37i9dQZF1DWWzQTBs5BHX9": 2005, "https://open.spotify.com/playlist/37i9dQZF1DWTWdbR13PQYH": 2004, "https://open.spotify.com/playlist/37i9dQZF1DXaW8fzPh9b08": 2003, "https://open.spotify.com/playlist/37i9dQZF1DX0P7PzzKwEKl": 2002, "https://open.spotify.com/playlist/37i9dQZF1DX9Ol4tZWPH6V": 2001, "https://open.spotify.com/playlist/37i9dQZF1DWUZv12GM5cFk": 2000}

# %% [markdown]
# ## Data Collection
#
# - Data collection was quite the challenge for this project!  I leveraged the spotipy library, on-the-fly learning, and previous work done by github community members to assist.  I specify each step below to get to the end product: detailed track information on 255,096 tracks from the years 2000 - 2021.  This includes 1,863 songs that placed in the Top Hits on spotify for a given year.

# %% [markdown]
# #### WORKING CODE, MARKDOWN FOR NOW
# # function to get information on top tracks, passing in the playlist URI
#
# track_names = []
# track_ids = []
# track_uris = []
# artist_names = []
# album_release_dates = []
# track_years = []
# popular_years = []
#
# def tophitsyear(url):
#     for track in sp.playlist_tracks(url)["items"]:
#         track_name = track["track"]["name"]
#         track_names.append(track_name)
#         track_id = track["track"]["id"]
#         track_ids.append(track_id)
#         track_uri = track["track"]["uri"]
#         track_uris.append(track_uri)
#         #artist_name = track["track"]["artists"] # too difficult to get
#         #artist_names.append(artist_name)
#         album_release_date = track["track"]["album"]["release_date"]
#         album_release_dates.append(album_release_date)
#         track_year = track["track"]["album"]["release_date"].split("-")[0]
#         track_years.append(track_year)
#         popular_year = YearDictionary[(url)]
#         popular_years.append(popular_year)
#         #print(popular_year)
#         #track_years.append(track_year)
#         #print(track_name, track_id, track_uri)
#         #return track_name, track_id, track_uri
#     #return track_names, track_ids, track_years, popular_year
#     #return track_name, track_id, track_uri, album_release_date, popular_year
#
# #tophitsyear(allLinks2)
# #empty_list = pd.DataFrame(empty_list)
# #print(popular_years)

# %% [markdown]
# #use list comprehension with function
# final_list1 = [tophitsyear(url) for url in allLinks]
#
# print(final_list1)

# %% [markdown]
# #### WORKING CODE, MARKDOWN FOR NOW
# # code to create dataframe from populated lists
# df = pd.DataFrame(list(zip(track_uris, track_ids, track_names, album_release_dates, track_years, popular_years)), columns=['track_uri', 'track_id', 'track_name', 'album_release_date', 'track_year', 'popular_year'])
# df.head()
# #df.shape

# %% [markdown]
# #### WORKING CODE, MARKDOWN FOR NOW
# track_uris2 = df['track_uri']
# identifier_list = track_uris2.values.tolist()
# print(identifier_list)

# %% [markdown]
# #### WORKING CODE, MARKDOWN FOR NOW
# AudioFeatures2 = [sp.audio_features(identifier)[0] for identifier in track_uris2]
# print(AudioFeatures2)

# %% [markdown]
# #### WORKING CODE, MARKDOWN FOR NOW
# # Use to read AudrioFeatures2 that was created from list comprehension
# df5 = pd.json_normalize(AudioFeatures2)
# print(df5)

# %% [markdown]
# #### Steps below were to get all song audio features for years 2000-2021

# %% [markdown]
# #### WORKING CODE, MARKDOWN FOR NOW
# # Initializing lists for basic track details
# artist_name = []
# artist_id = []
# album_name = []
# album_id = []
# track_name = []
# track_id = []
# track_pop = []
# track_year = []
# track_spotify_genre = []
# track_uri = []
#
# # Initiating lists for track audio features
# key = []
# acousticness = []
# danceability = []
# duration_ms = []
# energy = []
# instrumentalness = []
# liveness = []
# loudness = []
# mode = []
# speechiness = []
# tempo = []
# time_signature = []
# valence = []
#
# # Initializing genre
# artist_genre = []

# %% [markdown]
# #### Below code is to retrieve collection of song ids and basic track details - 50 tracks per. I had to run two years at a time to prevent it from timing out

# %% [markdown]
# #### WORKING CODE, MARKDOWN FOR NOW
# for genre in ['hip-hop', 'house','indie','pop','r&b','rock', 'soundtrack', 'jazz', 'classical', 'country', 'dance', 'alternative', 'movie', 'world', 'blues']:
#   for year in range(2020,2022):
#       query = "genre:" + genre + " year:" + str(year)
#       for i in range(0,1000,50):
#           track_results = sp.search(q=query, type='track', limit=50, offset=i) # change 'q=' argument for year
#           for item in track_results['tracks']['items']:
#               artist_name.append(item['album']['artists'][0]['name'])
#               artist_id.append(item['album']['artists'][0]['id'])
#               track_name.append(item['name'])
#               track_id.append(item['id'])
#               track_pop.append(item['popularity'])
#               track_year.append(year)
#               track_spotify_genre.append(genre)
#               #album_name.append(item['album']['name'])
#               #album_id.append(item['album']['id'])
#               track_uri.append(item['uri'])
#
# len(artist_name)

# %%
#dataset = pd.read_csv("../Data/AllSongs 2000-2021.csv")

# %% [markdown]
# #### WORKING CODE, MARKDOWN FOR NOW
# track_ids = dataset.track_id
# track_ids.head()

# %% [markdown]
# ### Code below retrieves all audio features for the given track ids

# %% [markdown]
# #### WORKING CODE, MARKDOWN FOR NOW
#
# # this gets all audio features for the given track ids
# for i in range(0,len(track_ids),50):
#   track_features = sp.audio_features(track_ids[i:i+50]) # returns features of first 50 tracks
#   for j in range(0,len(track_features)): # iterate over those 50 tracks
#     if track_features[j] is None:  # if track does not have audio features from spotify
#       track_features[j] = {}
#     key.append(track_features[j].get('key', np.nan))
#     acousticness.append(track_features[j].get('acousticness', np.nan))
#     danceability.append(track_features[j].get('danceability', np.nan))
#     duration_ms.append(track_features[j].get('duration_ms', np.nan))
#     energy.append(track_features[j].get('energy', np.nan))
#     instrumentalness.append(track_features[j].get('instrumentalness', np.nan))
#     liveness.append(track_features[j].get('liveness', np.nan))
#     loudness.append(track_features[j].get('loudness', np.nan))
#     mode.append(track_features[j].get('mode', np.nan))
#     speechiness.append(track_features[j].get('speechiness', np.nan))
#     tempo.append(track_features[j].get('tempo', np.nan))
#     time_signature.append(track_features[j].get('time_signature', np.nan))
#     valence.append(track_features[j].get('valence', np.nan))

# %% [markdown]
# ### Code below retrieves second artists on tracks
#
# I'll use this data to create a "collaboration" variable

# %% [markdown]
# #### WORKING CODE, MARKDOWN FOR NOW
#
# # get second artist on tracks
# for genre in ['hip-hop', 'house','indie','pop','r&b','rock', 'soundtrack', 'jazz', 'classical', 'country', 'dance', 'alternative', 'movie', 'world', 'blues']:
#     for year in range(2020,2023):
#           query = "genre:" + genre + " year:" + str(year)
#           for i in range(0,1000,50):
#               track_results = sp.search(q=query, type='track', limit=50, offset=i) # change 'q=' argument for year
#               for item in track_results['tracks']['items']:
#                     try:
#                         second_artist_name.append(item['album']['artists'][1]['name'])
#                         track_id.append(item['id'])
#                         track_uri.append(item['uri'])
#                     except:
#                         pass

# %% [markdown]
# Below code creates dataframe of audio features

# %% [markdown]
# #### WORKING CODE, MARKDOWN FOR NOW
#
# # create dataframe of audio features
# AllTracksAudio = pd.DataFrame({"track_id":track_ids,
#                    "key":key,
#                     "acousticness":acousticness,
#                     "danceability":danceability,
#                     "duration_ms":duration_ms,
#                     "energy":energy,
#                     "instrumentalness":instrumentalness,
#                     "liveness":liveness,
#                     "loudness":loudness,
#                     "mode":mode,
#                     "speechiness":speechiness,
#                     "tempo":tempo,
#                     "time_signature":time_signature,
#                     "valence":valence,
#                     })

# %% [markdown]
# ## Combining datasets
#
# At this point, I now have data collected, but disperesed among different files.
#
# - AllSongsAudioFeatures.csv: songs with all audio features from 2000-2021. contains audio features on 315,618 songs. I will use this as the primary file to merge data into.  There are about 60,000 duplicate track_ids that we want to drop
# - AllSongs.csv: high-level informational data (track_name, artist_name, track_genre, popularity) on 315,618 songs
# - AllCharts 2000-2021.csv: all of the Top 100 songs in each year from 2000-2021
# - SecondArtists.csv: second artists on tracks from 2000-2021
# - artists.csv: used this file to pull artist countries
# - collab_columns.csv: additional file I worked on to come up with collaborations
# - album_ratings.cvs: file for retrieving record label information for tracks

# %%
# load AllSongsAudioFeatures
AllSongsAudioFeatures = pd.read_csv("../Data/AllSongsAudioFeatures.csv", index_col =[0])
AllSongsAudioFeatures.drop_duplicates(keep='first', inplace=True) # drop ~60,000 rows that don't have unique track_ID

# %%
#confirm that dupclicates are removed
AllSongsAudioFeatures.track_id.value_counts()
# Out:
# 3yfqSUWxFvZELEM4PmlwIR    1
# 0r3ur5jBMpjkcrqbVVvgs7    1
# 4lXBIshfa0juWxi6odtLHt    1
# 4iddUbzyhbLEqhsVcZmc7u    1
# 4OfCkjpcpqKgr9igYyOSHm    1
#                          ..
# 5yqO0ETHCWHhy1Jf4ltayp    1
# 7A5uV4KrkkOO7ZipSPCAI6    1
# 6rZwfQkFFafuyU1SDSBx6u    1
# 5elDLvpi4MB1NT02PjbgtE    1
# 0IUtfOQZrk5NTuor7XvAW0    1
# Name: track_id, Length: 255098, dtype: int64

# %%
len(AllSongsAudioFeatures)
# Out:
# 255098

# %%
AllSongsAudioFeatures.shape
# Out:
# (255098, 14)

# %%
# load AllSongs
AllSongs = pd.read_csv("../Data/AllSongs 2000-2021.csv", index_col =[0])
AllSongs.drop_duplicates(subset='track_id', keep='first', inplace=True) # drop ~60,000 rows that don't have unique track_ID

# %%
AllSongs.shape
# Out:
# (267210, 8)

# %%
# load AllCharts
AllCharts = pd.read_csv("../Data/AllCharts 2000-2021.csv", index_col =[0])
AllCharts.drop_duplicates(subset='track_id', keep='first', inplace=True) # drop second value of 96 songs that appeared in the Top 100 list in two different years

# %%
AllCharts.shape
# Out:
# (2104, 7)

# %%
#check for missing values
AllCharts.isna().sum()
# Out:
# track_uri             0
# track_id              0
# track_name            0
# album_release_date    0
# track_year            0
# popular_year          0
# Top100                0
# dtype: int64

# %%
# load second artists
SecondArtists = pd.read_csv("../Data/SecondArtists.csv", index_col =[0])
SecondArtists.drop_duplicates(keep='first', inplace=True) #

# %%
AllSongs.track_name.value_counts()
# Out:
# Home                                 122
# Silent Night                         120
# Winter Wonderland                    112
# Intro                                 92
# O Holy Night                          88
#                                     ...
# Theme From 27 Dresses                  1
# Nim's Island                           1
# Rooftop Camp Out - Score               1
# Formation Of The Terra Cotta Army      1
# Cheek To Cheek - Live                  1
# Name: track_name, Length: 196942, dtype: int64

# %%
# load artist deatil
artist_detail = pd.read_csv("../Data/artists.csv", index_col =[0])
artist_detail.drop_duplicates(keep='first', inplace=True) #
# Out:
# /var/folders/rc/20gvvbw10mg1xrcm82p5g4tm0000gn/T/ipykernel_83406/513813650.py:2: DtypeWarning: Columns (2,4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   artist_detail = pd.read_csv("../Data/artists.csv", index_col =[0])

# %%
index_names = AllSongs[ (AllSongs['track_name'] == AllSongs['track_name']) & (AllSongs['art_name'] == AllSongs['art_name'])].index

# %%
len(index_names)
# Out:
# 267208

# %% [markdown]
# AllSongs.drop(index_names, inplace = True)

# %% [markdown]
# len(AllSongs)

# %%
AllSongs.track_name.value_counts()
# Out:
# Home                                 122
# Silent Night                         120
# Winter Wonderland                    112
# Intro                                 92
# O Holy Night                          88
#                                     ...
# Theme From 27 Dresses                  1
# Nim's Island                           1
# Rooftop Camp Out - Score               1
# Formation Of The Terra Cotta Army      1
# Cheek To Cheek - Live                  1
# Name: track_name, Length: 196942, dtype: int64

# %%
AllSongsAudioFeatures.head(5)
# Out:
#                  track_id  key  acousticness  danceability  duration_ms  \
# 0  3yfqSUWxFvZELEM4PmlwIR    5        0.0302         0.949       284200
# 1  0I3q5fE6wg7LIfHGngUTnV    4        0.1430         0.843       270507
# 2  3UmaczJpikHgJFyBTAJVoz    6        0.0371         0.780       404107
# 3  3Gf5nttwcX9aaSQXRWidEZ    7        0.0616         0.850       291782
# 4  6glsMWIMIxQ4BedzLqGVi4    5        0.0281         0.725       240027
#
#    energy  instrumentalness  liveness  loudness  mode  speechiness    tempo  \
# 0   0.661          0.000000    0.0454    -4.244     0       0.0572  104.504
# 1   0.806          0.000000    0.0771    -5.946     0       0.2690   94.948
# 2   0.768          0.000002    0.5180    -4.325     0       0.2380   80.063
# 3   0.700          0.000002    0.2440    -6.490     1       0.0478  101.875
# 4   0.640          0.000000    0.0990    -7.905     0       0.3320  166.028
#
#    time_signature  valence
# 0               4    0.760
# 1               4    0.613
# 2               4    0.507
# 3               4    0.722
# 4               3    0.915

# %%
AllSongs.head(5)
# Out:
#                  track_id           track_name  track_year  \
# 0  3yfqSUWxFvZELEM4PmlwIR  The Real Slim Shady        2000
# 1  0I3q5fE6wg7LIfHGngUTnV          Ms. Jackson        2000
# 2  3UmaczJpikHgJFyBTAJVoz                 Stan        2000
# 3  3Gf5nttwcX9aaSQXRWidEZ          Ride Wit Me        2000
# 4  6glsMWIMIxQ4BedzLqGVi4   So Fresh, So Clean        2000
#
#   track_spotify_genre art_name                  art_id  \
# 0             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 1             hip-hop  Outkast  1G9G7WwrXka3Z1r7aIDjI7
# 2             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 3             hip-hop    Nelly  2gBjLmx6zQnFGQJCAQpRgw
# 4             hip-hop  Outkast  1G9G7WwrXka3Z1r7aIDjI7
#
#                               track_uri  track_pop
# 0  spotify:track:3yfqSUWxFvZELEM4PmlwIR         88
# 1  spotify:track:0I3q5fE6wg7LIfHGngUTnV         82
# 2  spotify:track:3UmaczJpikHgJFyBTAJVoz         85
# 3  spotify:track:3Gf5nttwcX9aaSQXRWidEZ         75
# 4  spotify:track:6glsMWIMIxQ4BedzLqGVi4         72

# %% [markdown]
# ### Begin merges

# %%
# get all audio features for all tracks
df1 = pd.merge(AllSongs, AllSongsAudioFeatures, on='track_id', how='left')

# %%
df1.shape
# Out:
# (267210, 21)

# %%
df1.head(5)
# Out:
#                  track_id           track_name  track_year  \
# 0  3yfqSUWxFvZELEM4PmlwIR  The Real Slim Shady        2000
# 1  0I3q5fE6wg7LIfHGngUTnV          Ms. Jackson        2000
# 2  3UmaczJpikHgJFyBTAJVoz                 Stan        2000
# 3  3Gf5nttwcX9aaSQXRWidEZ          Ride Wit Me        2000
# 4  6glsMWIMIxQ4BedzLqGVi4   So Fresh, So Clean        2000
#
#   track_spotify_genre art_name                  art_id  \
# 0             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 1             hip-hop  Outkast  1G9G7WwrXka3Z1r7aIDjI7
# 2             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 3             hip-hop    Nelly  2gBjLmx6zQnFGQJCAQpRgw
# 4             hip-hop  Outkast  1G9G7WwrXka3Z1r7aIDjI7
#
#                               track_uri  track_pop  key  acousticness  ...  \
# 0  spotify:track:3yfqSUWxFvZELEM4PmlwIR         88  5.0        0.0302  ...
# 1  spotify:track:0I3q5fE6wg7LIfHGngUTnV         82  4.0        0.1430  ...
# 2  spotify:track:3UmaczJpikHgJFyBTAJVoz         85  6.0        0.0371  ...
# 3  spotify:track:3Gf5nttwcX9aaSQXRWidEZ         75  7.0        0.0616  ...
# 4  spotify:track:6glsMWIMIxQ4BedzLqGVi4         72  5.0        0.0281  ...
#
#    duration_ms  energy  instrumentalness  liveness  loudness  mode  \
# 0     284200.0   0.661          0.000000    0.0454    -4.244   0.0
# 1     270507.0   0.806          0.000000    0.0771    -5.946   0.0
# 2     404107.0   0.768          0.000002    0.5180    -4.325   0.0
# 3     291782.0   0.700          0.000002    0.2440    -6.490   1.0
# 4     240027.0   0.640          0.000000    0.0990    -7.905   0.0
#
#    speechiness    tempo  time_signature  valence
# 0       0.0572  104.504             4.0    0.760
# 1       0.2690   94.948             4.0    0.613
# 2       0.2380   80.063             4.0    0.507
# 3       0.0478  101.875             4.0    0.722
# 4       0.3320  166.028             3.0    0.915
#
# [5 rows x 21 columns]

# %%
AllCharts.head()
# Out:
#                               track_uri                track_id  \
# 0  spotify:track:6naxalmIoLFWR0siv8dnQQ  6naxalmIoLFWR0siv8dnQQ
# 1  spotify:track:2m1hi0nfMR9vdGC8UcrnwU  2m1hi0nfMR9vdGC8UcrnwU
# 2  spotify:track:3y4LxiYMgDl4RethdzpmNe  3y4LxiYMgDl4RethdzpmNe
# 3  spotify:track:0v1XpBHnsbkCn7iJ9Ucr1l  0v1XpBHnsbkCn7iJ9Ucr1l
# 4  spotify:track:62bOmKYxYg7dhrC6gH9vFn  62bOmKYxYg7dhrC6gH9vFn
#
#                track_name album_release_date  track_year  popular_year Top100
# 0  Oops!...I Did It Again         2000-05-16        2000          2000      Y
# 1    All The Small Things         1999-06-01        1999          2000      Y
# 2                 Breathe         1999-11-09        1999          2000      Y
# 3            It's My Life         2000-01-01        2000          2000      Y
# 4             Bye Bye Bye         2000-03-21        2000          2000      Y

# %%
#
#df1 = df1.merge(AllCharts[['album_release_date', 'popular_year', 'Top100']], on='track_id', how='left')
df1 = pd.merge(df1, AllCharts[['track_id', 'album_release_date', 'popular_year', 'Top100']], on='track_id', how='left')

# %%
df1.head(8)

#df1.isna().sum()
# Out:
#                  track_id                  track_name  track_year  \
# 0  3yfqSUWxFvZELEM4PmlwIR         The Real Slim Shady        2000
# 1  0I3q5fE6wg7LIfHGngUTnV                 Ms. Jackson        2000
# 2  3UmaczJpikHgJFyBTAJVoz                        Stan        2000
# 3  3Gf5nttwcX9aaSQXRWidEZ                 Ride Wit Me        2000
# 4  6glsMWIMIxQ4BedzLqGVi4          So Fresh, So Clean        2000
# 5  23wfXwnsPZYe5A1xXRHb3J                The Way I Am        2000
# 6  3wMUvT6eIw2L5cZFG1yH9j  Country Grammar (Hot Shit)        2000
# 7  5eGEc27nnhtmcOh6RC890a                    Kill You        2000
#
#   track_spotify_genre art_name                  art_id  \
# 0             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 1             hip-hop  Outkast  1G9G7WwrXka3Z1r7aIDjI7
# 2             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 3             hip-hop    Nelly  2gBjLmx6zQnFGQJCAQpRgw
# 4             hip-hop  Outkast  1G9G7WwrXka3Z1r7aIDjI7
# 5             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 6             hip-hop    Nelly  2gBjLmx6zQnFGQJCAQpRgw
# 7             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
#
#                               track_uri  track_pop   key  acousticness  ...  \
# 0  spotify:track:3yfqSUWxFvZELEM4PmlwIR         88   5.0       0.03020  ...
# 1  spotify:track:0I3q5fE6wg7LIfHGngUTnV         82   4.0       0.14300  ...
# 2  spotify:track:3UmaczJpikHgJFyBTAJVoz         85   6.0       0.03710  ...
# 3  spotify:track:3Gf5nttwcX9aaSQXRWidEZ         75   7.0       0.06160  ...
# 4  spotify:track:6glsMWIMIxQ4BedzLqGVi4         72   5.0       0.02810  ...
# 5  spotify:track:23wfXwnsPZYe5A1xXRHb3J         75   4.0       0.14400  ...
# 6  spotify:track:3wMUvT6eIw2L5cZFG1yH9j         69   2.0       0.00689  ...
# 7  spotify:track:5eGEc27nnhtmcOh6RC890a         70  11.0       0.15500  ...
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.0454    -4.244   0.0       0.0572  104.504             4.0    0.760
# 1    0.0771    -5.946   0.0       0.2690   94.948             4.0    0.613
# 2    0.5180    -4.325   0.0       0.2380   80.063             4.0    0.507
# 3    0.2440    -6.490   1.0       0.0478  101.875             4.0    0.722
# 4    0.0990    -7.905   0.0       0.3320  166.028             3.0    0.915
# 5    0.3090    -2.692   0.0       0.2650   87.248             4.0    0.315
# 6    0.1420    -6.822   1.0       0.1080  162.831             4.0    0.565
# 7    0.2960    -8.268   1.0       0.3790  106.991             4.0    0.677
#
#    album_release_date  popular_year  Top100
# 0          2000-05-23        2000.0       Y
# 1          2000-10-31        2001.0       Y
# 2          2000-05-23        2001.0       Y
# 3          2000-06-27        2001.0       Y
# 4                 NaN           NaN     NaN
# 5                 NaN           NaN     NaN
# 6          2000-06-27        2000.0       Y
# 7                 NaN           NaN     NaN
#
# [8 rows x 24 columns]

# %%
artist_detail.head(2)
# Out:
#                                       artist_mb artist_lastfm      country_mb  \
# mbid
# cc197bad-dc9c-440d-a5b5-d52ba2e14234   Coldplay      Coldplay  United Kingdom
# a74b1b7f-71a5-4011-9441-d0b5e4122711  Radiohead     Radiohead  United Kingdom
#
#                                       country_lastfm  \
# mbid
# cc197bad-dc9c-440d-a5b5-d52ba2e14234  United Kingdom
# a74b1b7f-71a5-4011-9441-d0b5e4122711  United Kingdom
#
#                                                                                 tags_mb  \
# mbid
# cc197bad-dc9c-440d-a5b5-d52ba2e14234  rock; pop; alternative rock; british; uk; brit...
# a74b1b7f-71a5-4011-9441-d0b5e4122711  rock; electronic; alternative rock; british; g...
#
#                                                                             tags_lastfm  \
# mbid
# cc197bad-dc9c-440d-a5b5-d52ba2e14234  rock; alternative; britpop; alternative rock; ...
# a74b1b7f-71a5-4011-9441-d0b5e4122711  alternative; alternative rock; rock; indie; el...
#
#                                       listeners_lastfm  scrobbles_lastfm  \
# mbid
# cc197bad-dc9c-440d-a5b5-d52ba2e14234         5381567.0       360111850.0
# a74b1b7f-71a5-4011-9441-d0b5e4122711         4732528.0       499548797.0
#
#                                       ambiguous_artist
# mbid
# cc197bad-dc9c-440d-a5b5-d52ba2e14234             False
# a74b1b7f-71a5-4011-9441-d0b5e4122711             False

# %%
df1 = pd.merge(df1, SecondArtists[['track_id', 'second_artist']], on='track_id', how='left')

# %%
df1 = pd.merge(df1, artist_detail[['country_mb', 'artist_mb']], how = 'left',
                left_on = 'art_name', right_on = 'artist_mb').drop(columns = ['artist_mb'])

# %%
df1.head()
# Out:
#                  track_id           track_name  track_year  \
# 0  3yfqSUWxFvZELEM4PmlwIR  The Real Slim Shady        2000
# 1  0I3q5fE6wg7LIfHGngUTnV          Ms. Jackson        2000
# 2  3UmaczJpikHgJFyBTAJVoz                 Stan        2000
# 3  3Gf5nttwcX9aaSQXRWidEZ          Ride Wit Me        2000
# 4  3Gf5nttwcX9aaSQXRWidEZ          Ride Wit Me        2000
#
#   track_spotify_genre art_name                  art_id  \
# 0             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 1             hip-hop  Outkast  1G9G7WwrXka3Z1r7aIDjI7
# 2             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 3             hip-hop    Nelly  2gBjLmx6zQnFGQJCAQpRgw
# 4             hip-hop    Nelly  2gBjLmx6zQnFGQJCAQpRgw
#
#                               track_uri  track_pop  key  acousticness  ...  \
# 0  spotify:track:3yfqSUWxFvZELEM4PmlwIR         88  5.0        0.0302  ...
# 1  spotify:track:0I3q5fE6wg7LIfHGngUTnV         82  4.0        0.1430  ...
# 2  spotify:track:3UmaczJpikHgJFyBTAJVoz         85  6.0        0.0371  ...
# 3  spotify:track:3Gf5nttwcX9aaSQXRWidEZ         75  7.0        0.0616  ...
# 4  spotify:track:3Gf5nttwcX9aaSQXRWidEZ         75  7.0        0.0616  ...
#
#    mode  speechiness    tempo  time_signature  valence  album_release_date  \
# 0   0.0       0.0572  104.504             4.0    0.760          2000-05-23
# 1   0.0       0.2690   94.948             4.0    0.613          2000-10-31
# 2   0.0       0.2380   80.063             4.0    0.507          2000-05-23
# 3   1.0       0.0478  101.875             4.0    0.722          2000-06-27
# 4   1.0       0.0478  101.875             4.0    0.722          2000-06-27
#
#    popular_year  Top100  second_artist     country_mb
# 0        2000.0       Y            NaN  United States
# 1        2001.0       Y            NaN            NaN
# 2        2001.0       Y            NaN  United States
# 3        2001.0       Y            NaN  United States
# 4        2001.0       Y            NaN            NaN
#
# [5 rows x 26 columns]

# %%
# there are a number of songs without audio information.  drop all values that don't have acousticness (could have used any variable)
df1 = df1[df1['acousticness'].notna()]
# note this leaves us with 1,863 observations that were Top100

# %%
df1.Top100.value_counts()
# Out:
# Y    2751
# Name: Top100, dtype: int64

# %%
# load data for collaborations
collab_columns = pd.read_csv("../Data/collab_columns.csv")

# %%
# merge collaborations data
df1 = df1.merge(collab_columns[['feat', 'Feat2', 'track_id']], how = 'left',
                left_on = 'track_id', right_on = 'track_id')

# %%
# load data for music labels
label_detail = pd.read_csv("../Data/album_ratings.csv")

# %%
df1.head()
# Out:
#                  track_id           track_name  track_year  \
# 0  3yfqSUWxFvZELEM4PmlwIR  The Real Slim Shady        2000
# 1  0I3q5fE6wg7LIfHGngUTnV          Ms. Jackson        2000
# 2  3UmaczJpikHgJFyBTAJVoz                 Stan        2000
# 3  3Gf5nttwcX9aaSQXRWidEZ          Ride Wit Me        2000
# 4  3Gf5nttwcX9aaSQXRWidEZ          Ride Wit Me        2000
#
#   track_spotify_genre art_name                  art_id  \
# 0             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 1             hip-hop  Outkast  1G9G7WwrXka3Z1r7aIDjI7
# 2             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 3             hip-hop    Nelly  2gBjLmx6zQnFGQJCAQpRgw
# 4             hip-hop    Nelly  2gBjLmx6zQnFGQJCAQpRgw
#
#                               track_uri  track_pop  key  acousticness  ...  \
# 0  spotify:track:3yfqSUWxFvZELEM4PmlwIR         88  5.0        0.0302  ...
# 1  spotify:track:0I3q5fE6wg7LIfHGngUTnV         82  4.0        0.1430  ...
# 2  spotify:track:3UmaczJpikHgJFyBTAJVoz         85  6.0        0.0371  ...
# 3  spotify:track:3Gf5nttwcX9aaSQXRWidEZ         75  7.0        0.0616  ...
# 4  spotify:track:3Gf5nttwcX9aaSQXRWidEZ         75  7.0        0.0616  ...
#
#      tempo  time_signature  valence  album_release_date  popular_year  Top100  \
# 0  104.504             4.0    0.760          2000-05-23        2000.0       Y
# 1   94.948             4.0    0.613          2000-10-31        2001.0       Y
# 2   80.063             4.0    0.507          2000-05-23        2001.0       Y
# 3  101.875             4.0    0.722          2000-06-27        2001.0       Y
# 4  101.875             4.0    0.722          2000-06-27        2001.0       Y
#
#    second_artist     country_mb   feat  Feat2
# 0            NaN  United States  FALSE  FALSE
# 1            NaN            NaN  FALSE  FALSE
# 2            NaN  United States  FALSE  FALSE
# 3            NaN  United States  FALSE  FALSE
# 4            NaN            NaN  FALSE  FALSE
#
# [5 rows x 28 columns]

# %%
# merge label data
df1 = df1.merge(label_detail['Label'], how = 'left',
                left_on = 'art_name', right_on = label_detail['Artist'])

# %%
df1.drop_duplicates(subset='track_id', keep='first', inplace=True)

# %% [markdown]
# ## With all of the datasets combined, we need to do some cleaning.  I noticed earlier that there are duplicate track_ids, track_uri, genres per song

# %%
# there are a number of songs without critical information.  drop all values that don't have an art_name
df1 = df1[df1['art_name'].notna()]
# note this leaves us with 1,903 observations that were Top100

# %%
# there are a number of songs without audio information.  drop all values that don't have acousticness (could have used any variable)
df1 = df1[df1['acousticness'].notna()]
# note this leaves us with 1,863 observations that were Top100

# %%
#df3.isna().sum()

# %%
df1.head(2)
# Out:
#                   track_id           track_name  track_year  \
# 0   3yfqSUWxFvZELEM4PmlwIR  The Real Slim Shady        2000
# 12  0I3q5fE6wg7LIfHGngUTnV          Ms. Jackson        2000
#
#    track_spotify_genre art_name                  art_id  \
# 0              hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 12             hip-hop  Outkast  1G9G7WwrXka3Z1r7aIDjI7
#
#                                track_uri  track_pop  key  acousticness  ...  \
# 0   spotify:track:3yfqSUWxFvZELEM4PmlwIR         88  5.0        0.0302  ...
# 12  spotify:track:0I3q5fE6wg7LIfHGngUTnV         82  4.0        0.1430  ...
#
#     time_signature  valence  album_release_date  popular_year  Top100  \
# 0              4.0    0.760          2000-05-23        2000.0       Y
# 12             4.0    0.613          2000-10-31        2001.0       Y
#
#     second_artist     country_mb   feat  Feat2                         Label
# 0             NaN  United States  FALSE  FALSE  Aftermath, Interscope, Shady
# 12            NaN            NaN  FALSE  FALSE                           NaN
#
# [2 rows x 29 columns]

# %%
#drop some columns that we don't need
df1 = df1.drop(['album_release_date', 'track_uri', 'art_id', 'track_year'], axis=1)

# %%
df1.head()
# Out:
#                   track_id           track_name track_spotify_genre art_name  \
# 0   3yfqSUWxFvZELEM4PmlwIR  The Real Slim Shady             hip-hop   Eminem
# 12  0I3q5fE6wg7LIfHGngUTnV          Ms. Jackson             hip-hop  Outkast
# 13  3UmaczJpikHgJFyBTAJVoz                 Stan             hip-hop   Eminem
# 25  3Gf5nttwcX9aaSQXRWidEZ          Ride Wit Me             hip-hop    Nelly
# 43  6glsMWIMIxQ4BedzLqGVi4   So Fresh, So Clean             hip-hop  Outkast
#
#     track_pop  key  acousticness  danceability  duration_ms  energy  ...  \
# 0          88  5.0        0.0302         0.949     284200.0   0.661  ...
# 12         82  4.0        0.1430         0.843     270507.0   0.806  ...
# 13         85  6.0        0.0371         0.780     404107.0   0.768  ...
# 25         75  7.0        0.0616         0.850     291782.0   0.700  ...
# 43         72  5.0        0.0281         0.725     240027.0   0.640  ...
#
#       tempo  time_signature  valence  popular_year  Top100  second_artist  \
# 0   104.504             4.0    0.760        2000.0       Y            NaN
# 12   94.948             4.0    0.613        2001.0       Y            NaN
# 13   80.063             4.0    0.507        2001.0       Y            NaN
# 25  101.875             4.0    0.722        2001.0       Y            NaN
# 43  166.028             3.0    0.915           NaN     NaN            NaN
#
#        country_mb   feat  Feat2                         Label
# 0   United States  FALSE  FALSE  Aftermath, Interscope, Shady
# 12            NaN  FALSE  FALSE                           NaN
# 13  United States  FALSE  FALSE  Aftermath, Interscope, Shady
# 25  United States  FALSE  FALSE              Universal Motown
# 43            NaN  FALSE  FALSE                           NaN
#
# [5 rows x 25 columns]

# %%
df1 = df1.rename(columns = {'track_pop':'track_popularity', 'track_spotify_genre':'track_genre', 'mode':'modality', 'art_name':'artist_name', 'country_mb':'artist_country'})

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 255096 entries, 0 to 1063084
# Data columns (total 25 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          255096 non-null  object
#  1   track_name        255096 non-null  object
#  2   track_genre       255096 non-null  object
#  3   artist_name       255096 non-null  object
#  4   track_popularity  255096 non-null  int64
#  5   key               255096 non-null  float64
#  6   acousticness      255096 non-null  float64
#  7   danceability      255096 non-null  float64
#  8   duration_ms       255096 non-null  float64
#  9   energy            255096 non-null  float64
#  10  instrumentalness  255096 non-null  float64
#  11  liveness          255096 non-null  float64
#  12  loudness          255096 non-null  float64
#  13  modality          255096 non-null  float64
#  14  speechiness       255096 non-null  float64
#  15  tempo             255096 non-null  float64
#  16  time_signature    255096 non-null  float64
#  17  valence           255096 non-null  float64
#  18  popular_year      1863 non-null    float64
#  19  Top100            1863 non-null    object
#  20  second_artist     24125 non-null   object
#  21  artist_country    183310 non-null  object
#  22  feat              255096 non-null  object
#  23  Feat2             255096 non-null  object
#  24  Label             101233 non-null  object
# dtypes: float64(14), int64(1), object(10)
# memory usage: 50.6+ MB

# %%
df1.nunique()
# Out:
# track_id            255096
# track_name          188539
# track_genre             15
# artist_name          22772
# track_popularity        95
# key                     12
# acousticness          5032
# danceability          1314
# duration_ms          84943
# energy                2729
# instrumentalness      5401
# liveness              1753
# loudness             30094
# modality                 2
# speechiness           1545
# tempo                89703
# time_signature           5
# valence               1710
# popular_year            22
# Top100                   1
# second_artist         6883
# artist_country         131
# feat                     3
# Feat2                    3
# Label                 2087
# dtype: int64

# %%
df1.isna().sum()
# Out:
# track_id                 0
# track_name               0
# track_genre              0
# artist_name              0
# track_popularity         0
# key                      0
# acousticness             0
# danceability             0
# duration_ms              0
# energy                   0
# instrumentalness         0
# liveness                 0
# loudness                 0
# modality                 0
# speechiness              0
# tempo                    0
# time_signature           0
# valence                  0
# popular_year        253233
# Top100              253233
# second_artist       230971
# artist_country       71786
# feat                     0
# Feat2                    0
# Label               153863
# dtype: int64

# %%
display(df1.loc[(df1['artist_country'].notnull()) & (df1['artist_name'] == 'Drake')])
# Out:
#                        track_id                             track_name  \
# 433183   3QLjDkgLh9AOEHlhQtDuhs                        Best I Ever Had
# 433368   5aooThgj87ID0vgiyvcjPM                            I'm Goin In
# 433525   0JaVdpmiex2EP7bBzyKVTa                          November 18th
# 433549   524wvipGqxPKYWxkjf9y46            Little Bit (feat. Lykke Li)
# 433577   4i3GraNMzBKze1WsVl38DS       Bria's Interlude (feat. Omarion)
# ...                         ...                                    ...
# 1005511  3mDFLytDotXo2p0rvfGbkA                            What's Next
# 1005568  6ZoZ4KGIDD23DohdVk0Ybw       Wants and Needs (feat. Lil Baby)
# 1005958  7wcWkzT1X75DguAwOWxlGt  Way 2 Sexy (with Future & Young Thug)
# 1016484  1PDP7mLiAMwhfmgIwzhOm2                     Yebba’s Heartbreak
# 1016558  2HSmyk2qMN8WQjuGhaQgCk                       Champagne Poetry
#
#         track_genre artist_name  track_popularity   key  acousticness  \
# 433183      hip-hop       Drake                77   1.0      0.190000
# 433368      hip-hop       Drake                63   1.0      0.038900
# 433525      hip-hop       Drake                60  11.0      0.579000
# 433549      hip-hop       Drake                61  11.0      0.099900
# 433577      hip-hop       Drake                60   2.0      0.209000
# ...             ...         ...               ...   ...           ...
# 1005511     hip-hop       Drake                54   0.0      0.012500
# 1005568     hip-hop       Drake                54   7.0      0.057400
# 1005958     hip-hop       Drake                51  11.0      0.000722
# 1016484         pop       Drake                78   8.0      0.967000
# 1016558         pop       Drake                76   6.0      0.758000
#
#          danceability  duration_ms  energy  ...    tempo  time_signature  \
# 433183          0.395     257690.0   0.922  ...  162.361             4.0
# 433368          0.662     225307.0   0.763  ...  170.031             4.0
# 433525          0.749     188189.0   0.476  ...   71.937             4.0
# 433549          0.758     230484.0   0.888  ...  120.392             4.0
# 433577          0.490     139575.0   0.507  ...  147.037             3.0
# ...               ...          ...     ...  ...      ...             ...
# 1005511         0.777     178154.0   0.580  ...  129.918             4.0
# 1005568         0.588     194090.0   0.412  ...  136.068             4.0
# 1005958         0.803     257605.0   0.596  ...  136.023             4.0
# 1016484         0.476     133763.0   0.161  ...  119.614             4.0
# 1016558         0.423     336511.0   0.667  ...   86.743             4.0
#
#          valence  popular_year  Top100  second_artist  artist_country   feat  \
# 433183    0.5580        2009.0       Y            NaN          Canada  FALSE
# 433368    0.5660           NaN     NaN            NaN          Canada  FALSE
# 433525    0.5340           NaN     NaN            NaN          Canada  FALSE
# 433549    0.7710           NaN     NaN            NaN          Canada      Y
# 433577    0.2370           NaN     NaN            NaN          Canada      Y
# ...          ...           ...     ...            ...             ...    ...
# 1005511   0.0636           NaN     NaN            NaN          Canada  FALSE
# 1005568   0.1210           NaN     NaN            NaN          Canada      Y
# 1005958   0.3260           NaN     NaN            NaN          Canada  FALSE
# 1016484   0.0908           NaN     NaN            NaN          Canada  FALSE
# 1016558   0.4960           NaN     NaN            NaN          Canada  FALSE
#
#          Feat2       Label
# 433183   FALSE  Cash Money
# 433368   FALSE  Cash Money
# 433525   FALSE  Cash Money
# 433549   FALSE  Cash Money
# 433577   FALSE  Cash Money
# ...        ...         ...
# 1005511  FALSE  Cash Money
# 1005568  FALSE  Cash Money
# 1005958  FALSE  Cash Money
# 1016484  FALSE  Cash Money
# 1016558  FALSE  Cash Money
#
# [296 rows x 25 columns]

# %% [markdown]
# There appear to be numerous artists named "Drake", to my suprise.

# %%
df1[df1.artist_country.notnull()]
# Out:
#                        track_id                             track_name  \
# 0        3yfqSUWxFvZELEM4PmlwIR                    The Real Slim Shady
# 13       3UmaczJpikHgJFyBTAJVoz                                   Stan
# 25       3Gf5nttwcX9aaSQXRWidEZ                            Ride Wit Me
# 44       23wfXwnsPZYe5A1xXRHb3J                           The Way I Am
# 56       3wMUvT6eIw2L5cZFG1yH9j             Country Grammar (Hot Shit)
# ...                         ...                                    ...
# 1063067  5kJKOO7eYN9PqHi2An3lRj                        So-Called Lover
# 1063069  2ByPBH09DXKl9KiWMQ3w7u                             Look Alive
# 1063070  1bAAzNDtN9VMcYrxCbOUsw             Love is Gonna Come at Last
# 1063073  5R61oQZBCkNZGSCnnIj7yo                             You Wonder
# 1063084  0IUtfOQZrk5NTuor7XvAW0  Can't You See What You're Doing To Me
#
#         track_genre         artist_name  track_popularity  key  acousticness  \
# 0           hip-hop              Eminem                88  5.0       0.03020
# 13          hip-hop              Eminem                85  6.0       0.03710
# 25          hip-hop               Nelly                75  7.0       0.06160
# 44          hip-hop              Eminem                75  4.0       0.14400
# 56          hip-hop               Nelly                69  2.0       0.00689
# ...             ...                 ...               ...  ...           ...
# 1063067       blues       Samantha Fish                21  7.0       0.00582
# 1063069       blues   Black Pistol Fire                23  9.0       0.02180
# 1063070       blues           Badfinger                23  2.0       0.04750
# 1063073       blues        Dinosaur Jr.                23  4.0       0.07780
# 1063084       blues  Joanne Shaw Taylor                24  6.0       0.22100
#
#          danceability  duration_ms  energy  ...    tempo  time_signature  \
# 0               0.949     284200.0   0.661  ...  104.504             4.0
# 13              0.780     404107.0   0.768  ...   80.063             4.0
# 25              0.850     291782.0   0.700  ...  101.875             4.0
# 44              0.785     290427.0   0.871  ...   87.248             4.0
# 56              0.865     287000.0   0.664  ...  162.831             4.0
# ...               ...          ...     ...  ...      ...             ...
# 1063067         0.429     185760.0   0.993  ...  170.074             4.0
# 1063069         0.677     192011.0   0.675  ...   94.013             4.0
# 1063070         0.555     218649.0   0.772  ...  111.037             4.0
# 1063073         0.586     183173.0   0.690  ...  114.498             4.0
# 1063084         0.472     265213.0   0.960  ...  142.430             3.0
#
#          valence  popular_year  Top100  second_artist  artist_country   feat  \
# 0          0.760        2000.0       Y            NaN   United States  FALSE
# 13         0.507        2001.0       Y            NaN   United States  FALSE
# 25         0.722        2001.0       Y            NaN   United States  FALSE
# 44         0.315           NaN     NaN            NaN   United States  FALSE
# 56         0.565        2000.0       Y            NaN   United States  FALSE
# ...          ...           ...     ...            ...             ...    ...
# 1063067    0.704           NaN     NaN            NaN   United States  FALSE
# 1063069    0.325           NaN     NaN            NaN   United States  FALSE
# 1063070    0.745           NaN     NaN            NaN  United Kingdom  FALSE
# 1063073    0.509           NaN     NaN            NaN   United States  FALSE
# 1063084    0.560           NaN     NaN            NaN  United Kingdom  FALSE
#
#          Feat2                         Label
# 0        FALSE  Aftermath, Interscope, Shady
# 13       FALSE  Aftermath, Interscope, Shady
# 25       FALSE              Universal Motown
# 44       FALSE  Aftermath, Interscope, Shady
# 56       FALSE              Universal Motown
# ...        ...                           ...
# 1063067  FALSE                           Ruf
# 1063069  FALSE                    Rifle Bird
# 1063070  FALSE                         Apple
# 1063073  FALSE                           NaN
# 1063084  FALSE                           NaN
#
# [183310 rows x 25 columns]

# %%
len(df1)
# Out:
# 255096

# %%
# there are many duplicate track_ids - let's eliminate any duplicates
df1.drop_duplicates(subset='track_id', keep='first', inplace=True)

# %%
len(df1)
# Out:
# 255096

# %%
display(df1.loc[(df1['artist_country'].notnull()) & (df1['artist_name'] == 'Drake') & (df1['artist_country'] != 'Canada')])
# Out:
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, feat, Feat2, Label]
# Index: []
#
# [0 rows x 25 columns]

# %%
df1['popular_year'] = df1['popular_year'].fillna(0)
df1['popular_year'] = df1['popular_year'].astype(int)

# %%
df1.Top100 = df1.Top100.fillna('N')

# %%
df1.head(10)
# Out:
#                   track_id                              track_name  \
# 0   3yfqSUWxFvZELEM4PmlwIR                     The Real Slim Shady
# 12  0I3q5fE6wg7LIfHGngUTnV                             Ms. Jackson
# 13  3UmaczJpikHgJFyBTAJVoz                                    Stan
# 25  3Gf5nttwcX9aaSQXRWidEZ                             Ride Wit Me
# 43  6glsMWIMIxQ4BedzLqGVi4                      So Fresh, So Clean
# 44  23wfXwnsPZYe5A1xXRHb3J                            The Way I Am
# 56  3wMUvT6eIw2L5cZFG1yH9j              Country Grammar (Hot Shit)
# 74  5eGEc27nnhtmcOh6RC890a                                Kill You
# 86  7lgvU7WnwcNZ8dbGUz8yhP                         Bitch Please II
# 98  4LwOrnuxJwR7C5Sw4liY4Z  What's Your Fantasy (Featuring Shawna)
#
#    track_genre artist_name  track_popularity   key  acousticness  \
# 0      hip-hop      Eminem                88   5.0       0.03020
# 12     hip-hop     Outkast                82   4.0       0.14300
# 13     hip-hop      Eminem                85   6.0       0.03710
# 25     hip-hop       Nelly                75   7.0       0.06160
# 43     hip-hop     Outkast                72   5.0       0.02810
# 44     hip-hop      Eminem                75   4.0       0.14400
# 56     hip-hop       Nelly                69   2.0       0.00689
# 74     hip-hop      Eminem                70  11.0       0.15500
# 86     hip-hop      Eminem                72   1.0       0.07830
# 98     hip-hop    Ludacris                63   6.0       0.16000
#
#     danceability  duration_ms  energy  ...    tempo  time_signature  valence  \
# 0          0.949     284200.0   0.661  ...  104.504             4.0    0.760
# 12         0.843     270507.0   0.806  ...   94.948             4.0    0.613
# 13         0.780     404107.0   0.768  ...   80.063             4.0    0.507
# 25         0.850     291782.0   0.700  ...  101.875             4.0    0.722
# 43         0.725     240027.0   0.640  ...  166.028             3.0    0.915
# 44         0.785     290427.0   0.871  ...   87.248             4.0    0.315
# 56         0.865     287000.0   0.664  ...  162.831             4.0    0.565
# 74         0.897     264400.0   0.559  ...  106.991             4.0    0.677
# 86         0.918     288200.0   0.586  ...   95.517             4.0    0.779
# 98         0.915     275907.0   0.790  ...  140.095             4.0    0.967
#
#     popular_year  Top100  second_artist  artist_country   feat  Feat2  \
# 0           2000       Y            NaN   United States  FALSE  FALSE
# 12          2001       Y            NaN             NaN  FALSE  FALSE
# 13          2001       Y            NaN   United States  FALSE  FALSE
# 25          2001       Y            NaN   United States  FALSE  FALSE
# 43             0       N            NaN             NaN  FALSE  FALSE
# 44             0       N            NaN   United States  FALSE  FALSE
# 56          2000       Y            NaN   United States  FALSE  FALSE
# 74             0       N            NaN   United States  FALSE  FALSE
# 86             0       N            NaN   United States  FALSE  FALSE
# 98             0       N            NaN   United States  FALSE      Y
#
#                            Label
# 0   Aftermath, Interscope, Shady
# 12                           NaN
# 13  Aftermath, Interscope, Shady
# 25              Universal Motown
# 43                           NaN
# 44  Aftermath, Interscope, Shady
# 56              Universal Motown
# 74  Aftermath, Interscope, Shady
# 86  Aftermath, Interscope, Shady
# 98                           NaN
#
# [10 rows x 25 columns]

# %%
df1.shape
# Out:
# (255096, 25)

# %% [markdown]
# ## Collaboration assignment section

# %%
df1['collaboration'] = "N"

# %%
df1.collaboration.value_counts()
# Out:
# N    255096
# Name: collaboration, dtype: int64

# %%
df1.loc[df1.second_artist.isna() == False, 'collaboration'] = "Y"

# %%
df1.loc[df1["feat"] == "Y", "collaboration"] = "Y"

# %%
df1.loc[df1["Feat2"] == "Y", "collaboration"] = "Y"

# %%
df1.collaboration.value_counts()
# Out:
# N    220634
# Y     34462
# Name: collaboration, dtype: int64

# %%
#drop collab columns since don't need them anymore
df1 = df1.drop(['feat', 'Feat2'], axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 255096 entries, 0 to 1063084
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          255096 non-null  object
#  1   track_name        255096 non-null  object
#  2   track_genre       255096 non-null  object
#  3   artist_name       255096 non-null  object
#  4   track_popularity  255096 non-null  int64
#  5   key               255096 non-null  float64
#  6   acousticness      255096 non-null  float64
#  7   danceability      255096 non-null  float64
#  8   duration_ms       255096 non-null  float64
#  9   energy            255096 non-null  float64
#  10  instrumentalness  255096 non-null  float64
#  11  liveness          255096 non-null  float64
#  12  loudness          255096 non-null  float64
#  13  modality          255096 non-null  float64
#  14  speechiness       255096 non-null  float64
#  15  tempo             255096 non-null  float64
#  16  time_signature    255096 non-null  float64
#  17  valence           255096 non-null  float64
#  18  popular_year      255096 non-null  int64
#  19  Top100            255096 non-null  object
#  20  second_artist     24125 non-null   object
#  21  artist_country    183310 non-null  object
#  22  Label             101233 non-null  object
#  23  collaboration     255096 non-null  object
# dtypes: float64(13), int64(2), object(9)
# memory usage: 48.7+ MB

# %% [markdown]
# # previous top 100 section

# %% [markdown]
# This section is intended to decipher if an artist has previously had a

# %%
df1.artist_name.value_counts()
# Out:
# Various Artists          14068
# Johann Sebastian Bach      845
# Annie Cordy                771
# Randy Newman               728
# Hillsong Worship           726
#                          ...
# Kae Tempest                  1
# Dave Mack                    1
# Earl Bostic                  1
# Kyan                         1
# Bob Margolin                 1
# Name: artist_name, Length: 22772, dtype: int64

# %%
df1['prevTop100'] = 'N'

# %%
df1[df1['artist_name'] == 'Eminem']
# Out:
#                        track_id  \
# 0        3yfqSUWxFvZELEM4PmlwIR
# 13       3UmaczJpikHgJFyBTAJVoz
# 44       23wfXwnsPZYe5A1xXRHb3J
# 74       5eGEc27nnhtmcOh6RC890a
# 86       7lgvU7WnwcNZ8dbGUz8yhP
# ...                         ...
# 1002424  3QVHSV8YKYq4L8tI5rnFgj
# 1002492  3CJbxqRQ0JNCqboWDNUUeX
# 1002504  086LXfSk4U5XEALardCE7k
# 1002820  7ccTcabbJlCJiIqtrSSwBk
# 1003827  7zl7kehxesNEo2pYkKXTSe
#
#                                                 track_name track_genre  \
# 0                                      The Real Slim Shady     hip-hop
# 13                                                    Stan     hip-hop
# 44                                            The Way I Am     hip-hop
# 74                                                Kill You     hip-hop
# 86                                         Bitch Please II     hip-hop
# ...                                                    ...         ...
# 1002424                                            Stepdad     hip-hop
# 1002492  I Will (feat. KXNG Crooked, Royce Da 5'9" & Jo...     hip-hop
# 1002504                           These Demons (feat. MAJ)     hip-hop
# 1002820                                Premonition - Intro     hip-hop
# 1003827        Killer (feat. Jack Harlow & Cordae) - Remix     hip-hop
#
#         artist_name  track_popularity   key  acousticness  danceability  \
# 0            Eminem                88   5.0        0.0302         0.949
# 13           Eminem                85   6.0        0.0371         0.780
# 44           Eminem                75   4.0        0.1440         0.785
# 74           Eminem                70  11.0        0.1550         0.897
# 86           Eminem                72   1.0        0.0783         0.918
# ...             ...               ...   ...           ...           ...
# 1002424      Eminem                55   1.0        0.0180         0.779
# 1002492      Eminem                54   8.0        0.0454         0.635
# 1002504      Eminem                54   1.0        0.0541         0.862
# 1002820      Eminem                54   1.0        0.0258         0.847
# 1003827      Eminem                68  11.0        0.0525         0.924
#
#          duration_ms  energy  ...    tempo  time_signature  valence  \
# 0           284200.0   0.661  ...  104.504             4.0    0.760
# 13          404107.0   0.768  ...   80.063             4.0    0.507
# 44          290427.0   0.871  ...   87.248             4.0    0.315
# 74          264400.0   0.559  ...  106.991             4.0    0.677
# 86          288200.0   0.586  ...   95.517             4.0    0.779
# ...              ...     ...  ...      ...             ...      ...
# 1002424     213413.0   0.805  ...  145.680             4.0    0.557
# 1002492     303000.0   0.543  ...   98.743             4.0    0.036
# 1002504     207320.0   0.789  ...  138.918             4.0    0.472
# 1002820     173893.0   0.637  ...  165.979             4.0    0.511
# 1003827     236666.0   0.730  ...   99.010             4.0    0.848
#
#          popular_year  Top100  second_artist  artist_country  \
# 0                2000       Y            NaN   United States
# 13               2001       Y            NaN   United States
# 44                  0       N            NaN   United States
# 74                  0       N            NaN   United States
# 86                  0       N            NaN   United States
# ...               ...     ...            ...             ...
# 1002424             0       N            NaN   United States
# 1002492             0       N            NaN   United States
# 1002504             0       N            NaN   United States
# 1002820             0       N            NaN   United States
# 1003827             0       N    Jack Harlow   United States
#
#                                 Label  collaboration prevTop100
# 0        Aftermath, Interscope, Shady              N          N
# 13       Aftermath, Interscope, Shady              N          N
# 44       Aftermath, Interscope, Shady              N          N
# 74       Aftermath, Interscope, Shady              N          N
# 86       Aftermath, Interscope, Shady              N          N
# ...                               ...            ...        ...
# 1002424  Aftermath, Interscope, Shady              N          N
# 1002492  Aftermath, Interscope, Shady              Y          N
# 1002504  Aftermath, Interscope, Shady              Y          N
# 1002820  Aftermath, Interscope, Shady              N          N
# 1003827  Aftermath, Interscope, Shady              Y          N
#
# [386 rows x 25 columns]

# %% [markdown]
# #### what I need to accomplish:
#
# for each row (track), determine if the artist of that track has previously had a track with a Top100 = "Y".  If this is true, then I want to populate the "prevTop100" column with a "Y". Note that this should only occur for Top100 songs that are not the first Top Hit for the artist (e.g. their first Top100 hit should have a "prevTop100" value of N).
#
# In the Britney Spears example below, the first two tracks, which were in the year 2000, would have prevTop100 values of "N", while all of the tracks in 2001 and forward would have a prevTop100 value of "Y".

# %%
#df1[df1['artist_name'] == 'Eminem' & df1['Top100'] == "Y"]
display(df1.loc[(df1['artist_name'] == 'Britney Spears') & (df1['Top100'] == 'Y')])
# Out:
#                       track_id  \
# 33729   6naxalmIoLFWR0siv8dnQQ
# 33819   2TTYIwTM2iLC1YOyHuhRMt
# 38079   6ldwfK0yWgTAlmIfuQkTYN
# 38717   5p0KCAuu5nrHpTuAIhHdLw
# 39198   1xg1yGPy1Y3YUf44s6TB1o
# 146115  6I9VzXrHxO9rA9A5euc8Ak
# 146831  7mS8RbJji2UZAaguRGsOCH
# 358656  6ic8OlLUNEATToEFU3xmaH
# 359239  2EvwLVrnYbCZEG6Kx5DCRy
# 359375  52K4Nl7eVNqUpUeJeWJlwT
# 456654  4fixebDZAVToLbUCuEloa2
# 456663  7jk7gqyEonmVVYahZN5zhW
# 456792  2hdy9Wt9qp7M7d0U3ossu2
# 566165  38iU2jg98IZZEIJPrP7aWD
# 566187  5cCAZS9VhLGEDV4NCfieeg
# 662547  3KliPMvk1EvFZu9cvkj8p1
#
#                                                track_name track_genre  \
# 33729                              Oops!...I Did It Again         pop
# 33819                                               Lucky         pop
# 38079                                     I'm a Slave 4 U         pop
# 38717                          Overprotected - Radio Edit         pop
# 39198                     I'm Not a Girl, Not Yet a Woman         pop
# 146115                                              Toxic         pop
# 146831  Me Against the Music (feat. Madonna) - LP Vers...         pop
# 358656                                         Gimme More         pop
# 359239                                        Piece of Me         pop
# 359375                                      Break the Ice         pop
# 456654                                          Womanizer         pop
# 456663                                             Circus         pop
# 456792                                      If U Seek Amy         pop
# 566165                                Till the World Ends         pop
# 566187                                         I Wanna Go         pop
# 662547                                         Work Bitch         pop
#
#            artist_name  track_popularity   key  acousticness  danceability  \
# 33729   Britney Spears                78   1.0       0.30000         0.751
# 33819   Britney Spears                67   8.0       0.26200         0.765
# 38079   Britney Spears                69   5.0       0.41500         0.847
# 38717   Britney Spears                63   0.0       0.03810         0.682
# 39198   Britney Spears                60   3.0       0.57900         0.534
# 146115  Britney Spears                82   5.0       0.02490         0.774
# 146831  Britney Spears                60   6.0       0.32000         0.804
# 358656  Britney Spears                79   2.0       0.25000         0.788
# 359239  Britney Spears                64  11.0       0.09020         0.769
# 359375  Britney Spears                61   5.0       0.68900         0.712
# 456654  Britney Spears                76  11.0       0.07300         0.724
# 456663  Britney Spears                74   6.0       0.14700         0.791
# 456792  Britney Spears                70   4.0       0.01920         0.717
# 566165  Britney Spears                65   8.0       0.02280         0.693
# 566187  Britney Spears                66   5.0       0.00379         0.696
# 662547  Britney Spears                69   9.0       0.15500         0.629
#
#         duration_ms  energy  ...    tempo  time_signature  valence  \
# 33729      211160.0   0.834  ...   95.053             4.0    0.894
# 33819      206227.0   0.791  ...   95.026             4.0    0.966
# 38079      203600.0   0.843  ...  110.027             4.0    0.963
# 38717      198600.0   0.894  ...   95.992             4.0    0.845
# 39198      231067.0   0.543  ...   78.996             4.0    0.418
# 146115     198800.0   0.838  ...  143.040             4.0    0.924
# 146831     223773.0   0.836  ...  120.046             4.0    0.850
# 358656     251240.0   0.844  ...  113.324             4.0    0.382
# 359239     212107.0   0.638  ...  115.007             4.0    0.782
# 359375     196053.0   0.911  ...  117.533             4.0    0.850
# 456654     224400.0   0.695  ...  139.000             4.0    0.235
# 456663     192360.0   0.733  ...  114.980             4.0    0.761
# 456792     216520.0   0.587  ...  129.954             4.0    0.544
# 566165     237947.0   0.705  ...  131.951             4.0    0.450
# 566187     210267.0   0.546  ...  130.002             4.0    0.787
# 662547     247960.0   0.824  ...  128.010             4.0    0.852
#
#         popular_year  Top100  second_artist  artist_country  Label  \
# 33729           2000       Y            NaN   United States   Jive
# 33819           2000       Y            NaN   United States   Jive
# 38079           2001       Y            NaN   United States   Jive
# 38717           2002       Y            NaN   United States   Jive
# 39198           2002       Y            NaN   United States   Jive
# 146115          2004       Y            NaN   United States   Jive
# 146831          2003       Y            NaN   United States   Jive
# 358656          2007       Y            NaN   United States   Jive
# 359239          2008       Y            NaN   United States   Jive
# 359375          2008       Y            NaN   United States   Jive
# 456654          2008       Y            NaN   United States   Jive
# 456663          2009       Y            NaN   United States   Jive
# 456792          2009       Y            NaN   United States   Jive
# 566165          2011       Y            NaN   United States   Jive
# 566187          2011       Y            NaN   United States   Jive
# 662547          2013       Y            NaN   United States   Jive
#
#         collaboration prevTop100
# 33729               N          N
# 33819               N          N
# 38079               N          N
# 38717               N          N
# 39198               N          N
# 146115              N          N
# 146831              Y          N
# 358656              N          N
# 359239              N          N
# 359375              N          N
# 456654              N          N
# 456663              N          N
# 456792              N          N
# 566165              N          N
# 566187              N          N
# 662547              N          N
#
# [16 rows x 25 columns]

# %%
df1[df1['Top100'] == 'Y']
# Out:
#                        track_id                                track_name  \
# 0        3yfqSUWxFvZELEM4PmlwIR                       The Real Slim Shady
# 12       0I3q5fE6wg7LIfHGngUTnV                               Ms. Jackson
# 13       3UmaczJpikHgJFyBTAJVoz                                      Stan
# 25       3Gf5nttwcX9aaSQXRWidEZ                               Ride Wit Me
# 56       3wMUvT6eIw2L5cZFG1yH9j                Country Grammar (Hot Shit)
# ...                         ...                                       ...
# 1017965  3eZYOQO4UzKrUDYDghtnFw                                test drive
# 1018611  4w47S36wQGBhGg073q3nt7                  TKN (feat. Travis Scott)
# 1043432  1raaNykBg1bDnWENUiglUA                            Break My Heart
# 1045196  0BI0hfbmqybnd3TezrDME3  Met Him Last Night (feat. Ariana Grande)
# 1045542  3XoflnowYPFRPOh3uFvHcm          Selfish Love (with Selena Gomez)
#
#         track_genre    artist_name  track_popularity  key  acousticness  \
# 0           hip-hop         Eminem                88  5.0       0.03020
# 12          hip-hop        Outkast                82  4.0       0.14300
# 13          hip-hop         Eminem                85  6.0       0.03710
# 25          hip-hop          Nelly                75  7.0       0.06160
# 56          hip-hop          Nelly                69  2.0       0.00689
# ...             ...            ...               ...  ...           ...
# 1017965         pop  Ariana Grande                65  9.0       0.02510
# 1018611         r&b        ROSALÍA                70  0.0       0.19200
# 1043432       dance       Dua Lipa                67  4.0       0.16700
# 1045196       dance    Demi Lovato                60  4.0       0.22000
# 1045542       dance       DJ Snake                61  5.0       0.02060
#
#          danceability  duration_ms  energy  ...    tempo  time_signature  \
# 0               0.949     284200.0   0.661  ...  104.504             4.0
# 12              0.843     270507.0   0.806  ...   94.948             4.0
# 13              0.780     404107.0   0.768  ...   80.063             4.0
# 25              0.850     291782.0   0.700  ...  101.875             4.0
# 56              0.865     287000.0   0.664  ...  162.831             4.0
# ...               ...          ...     ...  ...      ...             ...
# 1017965         0.698     122174.0   0.708  ...  115.036             4.0
# 1018611         0.776     129371.0   0.509  ...   94.634             4.0
# 1043432         0.730     221820.0   0.729  ...  113.012             4.0
# 1045196         0.538     204632.0   0.512  ...  144.978             4.0
# 1045542         0.723     168649.0   0.646  ...  110.971             4.0
#
#          valence  popular_year  Top100  second_artist  artist_country  \
# 0          0.760          2000       Y            NaN   United States
# 12         0.613          2001       Y            NaN             NaN
# 13         0.507          2001       Y            NaN   United States
# 25         0.722          2001       Y            NaN   United States
# 56         0.565          2000       Y            NaN   United States
# ...          ...           ...     ...            ...             ...
# 1017965    0.322          2021       Y            NaN   United States
# 1018611    0.485          2020       Y   Travis Scott           Spain
# 1043432    0.467          2020       Y            NaN  United Kingdom
# 1045196    0.120          2021       Y            NaN   United States
# 1045542    0.443          2021       Y   Selena Gomez          France
#
#                                 Label  collaboration prevTop100
# 0        Aftermath, Interscope, Shady              N          N
# 12                                NaN              N          N
# 13       Aftermath, Interscope, Shady              N          N
# 25                   Universal Motown              N          N
# 56                   Universal Motown              N          N
# ...                               ...            ...        ...
# 1017965                      Republic              N          N
# 1018611                           NaN              Y          N
# 1043432                        Warner              N          N
# 1045196                     Hollywood              Y          N
# 1045542                    Interscope              Y          N
#
# [1863 rows x 25 columns]

# %%
# create the dataframe to compare against
top100df = df1[df1['Top100'] == 'Y']
top100df.head(4)
# Out:
#                   track_id           track_name track_genre artist_name  \
# 0   3yfqSUWxFvZELEM4PmlwIR  The Real Slim Shady     hip-hop      Eminem
# 12  0I3q5fE6wg7LIfHGngUTnV          Ms. Jackson     hip-hop     Outkast
# 13  3UmaczJpikHgJFyBTAJVoz                 Stan     hip-hop      Eminem
# 25  3Gf5nttwcX9aaSQXRWidEZ          Ride Wit Me     hip-hop       Nelly
#
#     track_popularity  key  acousticness  danceability  duration_ms  energy  \
# 0                 88  5.0        0.0302         0.949     284200.0   0.661
# 12                82  4.0        0.1430         0.843     270507.0   0.806
# 13                85  6.0        0.0371         0.780     404107.0   0.768
# 25                75  7.0        0.0616         0.850     291782.0   0.700
#
#     ...    tempo  time_signature  valence  popular_year  Top100  \
# 0   ...  104.504             4.0    0.760          2000       Y
# 12  ...   94.948             4.0    0.613          2001       Y
# 13  ...   80.063             4.0    0.507          2001       Y
# 25  ...  101.875             4.0    0.722          2001       Y
#
#     second_artist  artist_country                         Label  \
# 0             NaN   United States  Aftermath, Interscope, Shady
# 12            NaN             NaN                           NaN
# 13            NaN   United States  Aftermath, Interscope, Shady
# 25            NaN   United States              Universal Motown
#
#     collaboration prevTop100
# 0               N          N
# 12              N          N
# 13              N          N
# 25              N          N
#
# [4 rows x 25 columns]

# %%
# in this first for loop, I'm trying to create a "temporary" dataframe that has each artist with a Top100 hit, and specifically find the year of their first Top100 hit
for artist in top100df['artist_name']:
    #temp_df = (top100df[top100df['artist_name'] == artist] & top100df[top100df['popular_year']].min())
    temp_df = df1.loc[(df1['artist_name'] == artist) & (df1['popular_year'].min())]
    print(temp_df)
# Out:
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# ...
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, popular_year, Top100, second_artist, artist_country, Label, collaboration, prevTop100]
# Index: []
#
# [0 rows x 25 columns]

# %%
# once I'm able to get that for loop right, I need to be able to

# %%
top100df.Top100.value_counts()
# Out:
# Y    1863
# Name: Top100, dtype: int64

# %%
for row in df1['prevTop100']:
    if df1['artist_name'] in top100df['artist_name']:
        print('yes')
    else:
        print('no')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [75], in <cell line: 1>()
#       1 for row in df1['prevTop100']:
# ----> 2     if df1['artist_name'] in top100df['artist_name']:
#       3         print('yes')
#       4     else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:1994, in NDFrame.__contains__(self, key)
#    1991 @final
#    1992 def __contains__(self, key) -> bool_t:
#    1993     """True if the key is in the info axis"""
# -> 1994     return key in self._info_axis
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/numeric.py:226, in NumericIndex.__contains__(self, key)
#     223 if not is_integer_dtype(self.dtype):
#     224     return super().__contains__(key)
# --> 226 hash(key)
#     227 try:
#     228     if is_float(key) and int(key) != key:
#     229         # otherwise the `key in self._engine` check casts e.g. 1.1 -> 1
#
# TypeError: unhashable type: 'Series'

# %%
# for row in df6['prev_Top100']:
#     if df6['Top100'] = 'N':
#         skip
#     else:    
#         if artist = df6["artist_name"]

# %%
for row in df1['prev_Top100']:
    artist = df1['artist_name']
    print(artist)
    #comp_df = df6.loc[(df6['artist_name'] == (artist))]
    #comp_df = df6.loc[(df6['artist_name'] == (artist)) & (df6['popular_year'] == 'Y')]
    #print(comp_df)

# %% [markdown]
# #### subset dataframe on the fly approach

# %% [markdown]
# #### create dictionary approach
# almost like if for each artist, you created a dictionary of years that they previously had a top 100, you could look up that list

# %% [markdown]
# one approach:
# embedded for loop where you look at previous dataframe
#
# another approach:
# join between two dataframes

# %% [markdown]
# #### write to CSV
# from pathlib import Path
# filepath = Path('/Users/gregwelliver/Desktop/springboard_files/Capstone Two - Music/Data/Merged_Data7.csv')
# filepath.parent.mkdir(parents=True, exist_ok=True)
# df7.to_csv(filepath)

# %% [markdown]
# ### Reference docs
#
# spotipy documentation
# https://spotipy.readthedocs.io/en/latest/#installation
#
# google sheet with links to top song playlists: https://docs.google.com/spreadsheets/d/10gRoHKIB1RFfxSvb83gzYkV33x5eMMI1RZoXSamFwPI/edit#gid=824975682
#
# github for project that I referenced to pull data: https://github.com/ekatnic/SpotifyApiExploration/blob/master/Spotify_Generate_Tracks.ipynb
#
# Proposal: https://docs.google.com/document/d/1rRzJV0hOaNMsBIjji8v1Cv8C3QUuZ6lUvYokZ5dif-A/edit
